# %%
from graph import *

# %%
g = Graph(10,.4,0,.5) #steps,contagiousness,
g.makeVerticesAndConnections(200,.7)
print(g)
g.update(50)
print(g)
g.resetGraph()
print "\n", g
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-8-e9276d5d443d> in <module>()
#       1 g = Graph(10,.4,0,.5) #steps,contagiousness,
# ----> 2 g.makeVerticesAndConnections(200,.7)
#       3 print(g)
#       4 g.update(50)
#       5 print(g)
#
# /home/students/doorjo01/research/summer2015/graph.py in makeVerticesAndConnections(self, numVertices, probOfConnection)
#      75
#      76     def makeVerticesAndConnections(self,numVertices,probOfConnection):
# ---> 77         self.makeVertices(numVertices)
#      78         self.makeConnections(probOfConnection)
#      79         self.saveOriginal()
#
# /home/students/doorjo01/research/summer2015/graph.py in saveOriginal(self)
#      70
#      71     def saveOriginal(self):
# ---> 72         '''This function saves the first state of the graph, after vertices and connections have been made'''
# ...

# %%
g.printHi()
