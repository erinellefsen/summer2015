# %%
import graph
import params
import group
import math
import utils
import collections
import matplotlib
import matplotlib.pyplot as plt
import pylab as pl
import numpy as np
# %matplotlib inline

# %%
fig = plt.figure()

vaccination = 0
colorlist = ['red','blue','green', 'gray']
for color in colorlist:
    Rlist = []
    for x in range(5):
        plist = [.1,.4,.6,.9]
        klist = [1,3,5,7,8]
        for p in plist:
            for k in klist:
                prams = params.Params(k,p,1000,0,vaccination*1000)
                g = graph.Graph(prams,True)
                g.update()
                Rlist = Rlist + [[g.calculateR(True), float(g.getR())/float(1000), float(vaccination)]]

        for p in plist:
            for k in klist:
                prams = params.Params(k,p,2000,0,vaccination*2000)
                g = graph.Graph(prams,True)
                g.update()
                Rlist = Rlist + [[g.calculateR(True), float(g.getR())/float(2000), float(vaccination)]]

        for p in plist:
            for k in klist:
                prams = params.Params(k,p,3000,0,vaccination*3000)
                g = graph.Graph(prams,True)
                g.update()
                Rlist = Rlist + [[g.calculateR(True), float(g.getR())/float(3000), float(vaccination)]]
    xlist = []
    ylist = []
    for item in Rlist:
        xlist = xlist +[item[0]]
        ylist = ylist + [item[1]]
    ax = fig.add_subplot(1,1,1)
    utils.plot_implicit2d(utils.continuousInfection, rangeX=(0,4),rangeY=(0,1),ax=ax)
    utils.plot_implicit2d(utils.continuousInfection2, rangeX=(0,4),rangeY=(0,1),ax=ax)
    utils.plot_implicit2d(utils.continuousInfection4, rangeX=(0,4),rangeY=(0,1),ax=ax)
    utils.plot_implicit2d(utils.continuousInfection6, rangeX=(0,4),rangeY=(0,1),ax=ax)
    plt.scatter(xlist,ylist, c = color)
    vaccination += .2
    print(Rlist)
# Out:
# utils.py:32: RuntimeWarning: divide by zero encountered in divide
#   return (np.log((2000-1)/(2000*(1-y)))-x*y)
# utils.py:35: RuntimeWarning: invalid value encountered in log
#   return (np.log((2000-1-400)/(2000*(1-y)-400))-x*y)
# utils.py:37: RuntimeWarning: invalid value encountered in log
#   return (np.log((2000-1-800)/(2000*(1-y)-800))-x*y)
# utils.py:39: RuntimeWarning: invalid value encountered in log
#   return (np.log((2000-1-1200)/(2000*(1-y)-1200))-x*y)
# [[0.5553999999999999, 0.002, 0.0], [1.4070319999999996, 0.001, 0.0], [2.4750784399999994, 0.001, 0.0], [2.7024220579999993, 0.003, 0.0], [2.5492287680399994, 0.636, 0.0], [2.064, 0.702, 0.0], [4.376288, 0.799, 0.0], [4.506064640000001, 0.766, 0.0], [5.0797054464, 0.771, 0.0], [4.60925960192, 0.743, 0.0], [3.0816, 0.749, 0.0], [5.035679999999999, 0.004, 0.0], [5.5169222399999995, 0.781, 0.0], [5.123591731199999, 0.778, 0.0], [5.66828279808, 0.774, 0.0], [4.6926000000000005, 0.779, 0.0], [4.881114, 0.746, 0.0], [5.21794782, 0.77, 0.0], [5.3659994634, 0.792, 0.0], [5.7099999429,